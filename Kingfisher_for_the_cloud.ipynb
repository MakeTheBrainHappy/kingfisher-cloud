# %% [markdown]
# <a href="https://colab.research.google.com/github/MakeTheBrainHappy/kingfisher-cloud/blob/main/Kingfisher_for_the_cloud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Kingfisher for the Cloud

# %% [markdown]
# Kingfisher is a fast and flexible program for procurement of sequence files (and their annotations) from public data sources, including the European Nucleotide Archive (ENA), NCBI SRA, Amazon AWS and Google Cloud. It's input is one or more "Run" accessions e.g. DRR001970, or a BioProject accessions e.g. PRJNA621514 or SRP260223.
#
# Copyright Ben Woodcroft 2019-2021. Licensed under GPL3+. See LICENSE.txt.
#
# *cloud version implemented by MakeTheBrainHappy ([GitHub](https://github.com/MakeTheBrainHappy) | [Instagram](https://www.instagram.com/makethebrainhappy/?hl=en) | [Twitter](https://twitter.com/makebrainhappy?lang=en) | [Website](https://www.makethebrainhappy.com) | [YouTube](https://www.youtube.com/channel/UCqsJuv5pWwoFgq3qOGBBsiw))*

# %% [markdown]
# ##Managing Software via BioConda

# %% [markdown]
# ![bioconda.png](data:image/png;base64,...)

# %% [markdown]
# There are numerous options for organizing your bioinformatics pipelines on your personal computer; each software developer offers multiple routes to download their packages. One of the easiest managers is BioConda which allows you to setup individual environments and easily install packages. Their repository includes over 8,000 different bioinformatics-specific software. This pipeline will mainly utilize BioConda for all package installs. Please see the following pages in order to learn more about installing BioConda on your own computer: [BioConda](https://bioconda.github.io/user/install.html) and [Managing Environments via Conda](https://docs.conda.io/projects/conda/en/latest/user-guide/tasks/manage-environments.html).

# %%
! wget https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
! chmod +x Miniconda3-py37_4.8.2-Linux-x86_64.sh
! bash ./Miniconda3-py37_4.8.2-Linux-x86_64.sh -b -f -p /usr/local
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')
# Out:
# --2022-01-10 19:50:34--  https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.130.3, 104.16.131.3, 2606:4700::6810:8203, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.130.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85055499 (81M) [application/x-sh]
# Saving to: ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh’
#
# Miniconda3-py37_4.8 100%[===================>]  81.12M   220MB/s    in 0.4s
#
# 2022-01-10 19:50:34 (220 MB/s) - ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh’ saved [85055499/85055499]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - asn1crypto==1.3.0=py37_0
#     - ca-certificates==2020.1.1=0
#     - certifi==2019.11.28=py37_0
#     - cffi==1.14.0=py37h2e261b9_0
#     - chardet==3.0.4=py37_1003
# ...

# %% [markdown]
# ##Kingfisher: fast and flexible program for procurement of sequence files

# %% [markdown]
# ![kingfisher_logo.png](data:image/png;base64,...)

# %% [markdown]
# Please read through the documentation for more information about the Kingfisher program: https://github.com/wwood/kingfisher-download
#
# These commands install this program within the Google Colaboratory environment.

# %%
! git clone https://github.com/MakeTheBrainHappy/kingfisher-download
# Out:
# Cloning into 'kingfisher-download'...
# remote: Enumerating objects: 693, done.
# remote: Counting objects: 100% (648/648), done.
# remote: Compressing objects: 100% (316/316), done.
# remote: Total 693 (delta 375), reused 505 (delta 249), pack-reused 45
# Receiving objects: 100% (693/693), 8.36 MiB | 32.43 MiB/s, done.
# Resolving deltas: 100% (395/395), done.

# %%
# %cd kingfisher-download
# Out:
# /content/kingfisher-download

# %%
! conda env update -n base --file kingfisher.yml
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.2
#   latest version: 4.11.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ...
# argparse-manpage-bir | 16 KB     | : 100% 1.0/1 [00:00<00:00,  3.20it/s]
# libnghttp2-1.43.0    | 790 KB    | : 100% 1.0/1 [00:00<00:00,  4.55it/s]
# docutils-0.15.2      | 742 KB    | : 100% 1.0/1 [00:00<00:00,  3.68it/s]
# xz-5.2.5             | 343 KB    | : 100% 1.0/1 [00:00<00:00,  8.16it/s]
# _openmp_mutex-4.5    | 22 KB     | : 100% 1.0/1 [00:00<00:00, 20.44it/s]
# pycosat-0.6.3        | 107 KB    | : 100% 1.0/1 [00:00<00:00, 18.07it/s]
# requests-2.27.1      | 53 KB     | : 100% 1.0/1 [00:00<00:00, 21.60it/s]
# libgfortran-ng-11.2. | 19 KB     | : 100% 1.0/1 [00:00<00:00, 28.08it/s]
# aria2-1.36.0         | 1.5 MB    | : 100% 1.0/1 [00:00<00:00,  2.47it/s]
# c-ares-1.18.1        | 113 KB    | : 100% 1.0/1 [00:00<00:00, 17.35it/s]
# ...

# %%
! conda install -c rpetit3 aspera-connect -y
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - aspera-connect
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     aspera-connect-3.9.6       |                0        34.3 MB  rpetit3
#     ca-certificates-2021.10.26 |       h06a4308_2         115 KB
#     conda-4.11.0               |   py39h06a4308_0        14.4 MB
#     ------------------------------------------------------------
#                                            Total:        48.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   aspera-connect     rpetit3/linux-64::aspera-connect-3.9.6-0
#
# The following packages will be UPDATED:
#
#   ca-certificates    conda-forge::ca-certificates-2021.10.~ --> pkgs/main::ca-certificates-2021.10.26-h06a4308_2
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
# ...

# %%
! wget -qO- https://download.asperasoft.com/download/sw/connect/3.9.8/ibm-aspera-connect-3.9.8.176272-linux-g2.12-64.tar.gz | tar xvz
# Out:
# ibm-aspera-connect-3.9.8.176272-linux-g2.12-64.sh

# %% [markdown]
# this command will pop up with an error message; please disregard

# %%
! ./ibm-aspera-connect-3.9.8.176272-linux-g2.12-64.sh
# Out:
# Installing IBM Aspera Connect
#
# This script cannot be run as root, IBM Aspera Connect must be installed per user.

# %%
# %cd ..
# Out:
# /content

# %% [markdown]
# Below is a sample command with a selected accession number (SRR13583274) which can be replaced with the command you require:

# %%
! /content/kingfisher-download/bin/kingfisher get -r SRR13583274 -m ena-ascp aws-http prefetch
# Out:
# 01/10/2022 07:55:54 PM INFO: Kingfisher v0.0.1-dev
# 01/10/2022 07:55:54 PM INFO: Attempting download method ena-ascp for run SRR13583274 ..
# 01/10/2022 07:55:54 PM INFO: Using aspera ssh key file: $HOME/.aspera/connect/etc/asperaweb_id_dsa.openssh
# 01/10/2022 07:55:54 PM INFO: Querying ENA for FTP paths for SRR13583274..
# 01/10/2022 07:55:56 PM INFO: Downloading 1 FTP read set(s): ftp.sra.ebi.ac.uk/vol1/fastq/SRR135/074/SRR13583274/SRR13583274_1.fastq.gz
# 01/10/2022 07:55:56 PM INFO: Running command: ascp -T -l 300m -P33001 -k 2 -i $HOME/.aspera/connect/etc/asperaweb_id_dsa.openssh era-fasp@fasp.sra.ebi.ac.uk:/vol1/fastq/SRR135/074/SRR13583274/SRR13583274_1.fastq.gz .
# 01/10/2022 07:56:08 PM WARNING: Error downloading from ENA with ASCP: Command ascp -T -l 300m -P33001 -k 2 -i $HOME/.aspera/connect/etc/asperaweb_id_dsa.openssh era-fasp@fasp.sra.ebi.ac.uk:/vol1/fastq/SRR135/074/SRR13583274/SRR13583274_1.fastq.gz . returned non-zero exit status 1.
# ...

# %% [markdown]
# ##Transfer Files to your Google Drive

# %% [markdown]
# Two convenience commands to move downloaded files to your Google Drive (permanent storage)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ```bash
# cp -r PATH_TO_LOCAL_FILE PATH_TO_DRIVE_LOCATION
# ```

# %%
! cp -r SRR13583274.fastq /content/drive/MyDrive/bioinformatics/
